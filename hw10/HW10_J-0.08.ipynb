# %% [markdown]
# # **Homework 10 - Adversarial Attack**

# %% [markdown]
# ## Enviroment & Download
#
# We make use of [pytorchcv](https://pypi.org/project/pytorchcv/) to obtain CIFAR-10 pretrained model, so we need to set up the enviroment first. We also need to download the data (200 images) which we want to attack.

# %%
# # set up environment
# !pip install pytorchcv
# !pip install imgaug

# # download
# !gdown --id 1t2UFQXr1cr5qLMBK2oN2rY1NDypi9Nyw --output data.zip

# # if the above link isn't available, try this one
# # !wget https://www.dropbox.com/s/lbpypqamqjpt2qz/data.zip

# # unzip
# !unzip ./data.zip

# %%
# !rm ./data.zip

# %%
import torch
import torch.nn as nn
from pytorchcv.model_provider import get_model as ptcv_get_model
import random
import numpy as np

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
batch_size = 8

def same_seeds(seed):
	  torch.manual_seed(seed)
	  if torch.cuda.is_available():
		    torch.cuda.manual_seed(seed)
		    torch.cuda.manual_seed_all(seed)
	  np.random.seed(seed)
	  random.seed(seed)
	  torch.backends.cudnn.benchmark = False
	  torch.backends.cudnn.deterministic = True
same_seeds(1126)

# %% [markdown]
# ## Global Settings
# #### **[NOTE]**: Don't change the settings here, or your generated image might not meet the constraint.
# * $\epsilon$ is fixed to be 8. But on **Data section**, we will first apply transforms on raw pixel value (0-255 scale) **by ToTensor (to 0-1 scale)** and then **Normalize (subtract mean divide std)**. $\epsilon$ should be set to $\frac{8}{255 * std}$ during attack.
#
# * Explaination (optional)
#     * Denote the first pixel of original image as $p$, and the first pixel of adversarial image as $a$.
#     * The $\epsilon$ constraints tell us $\left| p-a \right| <= 8$.
#     * ToTensor() can be seen as a function where $T(x) = x/255$.
#     * Normalize() can be seen as a function where $N(x) = (x-mean)/std$ where $mean$ and $std$ are constants.
#     * After applying ToTensor() and Normalize() on $p$ and $a$, the constraint becomes $\left| N(T(p))-N(T(a)) \right| = \left| \frac{\frac{p}{255}-mean}{std}-\frac{\frac{a}{255}-mean}{std} \right| = \frac{1}{255 * std} \left| p-a \right| <= \frac{8}{255 * std}.$
#     * So, we should set $\epsilon$ to be $\frac{8}{255 * std}$ after ToTensor() and Normalize().

# %%
# the mean and std are the calculated statistics from cifar_10 dataset
cifar_10_mean = (0.491, 0.482, 0.447) # mean for the three channels of cifar_10 images
cifar_10_std = (0.202, 0.199, 0.201) # std for the three channels of cifar_10 images

# convert mean and std to 3-dimensional tensors for future operations
mean = torch.tensor(cifar_10_mean).to(device).view(3, 1, 1)
std = torch.tensor(cifar_10_std).to(device).view(3, 1, 1)

epsilon = 8/255/std

# %%
root = './data' # directory for storing benign images
# benign images: images which do not contain adversarial perturbations
# adversarial images: images which include adversarial perturbations

# %% [markdown]
# ## Data
#
# Construct dataset and dataloader from root directory. Note that we store the filename of each image for future usage.

# %%
import os
import glob
import shutil
import numpy as np
from PIL import Image
from torchvision.transforms import transforms
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F



transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(cifar_10_mean, cifar_10_std)
])

class AdvDataset(Dataset):
    def __init__(self, data_dir, transform):
        self.images = []
        self.labels = []
        self.names = []
        '''
        data_dir
        ├── class_dir
        │   ├── class1.png
        │   ├── ...
        │   ├── class20.png
        '''
        for i, class_dir in enumerate(sorted(glob.glob(f'{data_dir}/*'))):
            images = sorted(glob.glob(f'{class_dir}/*'))
            self.images += images
            self.labels += ([i] * len(images))
            self.names += [os.path.relpath(imgs, data_dir) for imgs in images]
        self.transform = transform
    def __getitem__(self, idx):
        image = self.transform(Image.open(self.images[idx]))
        label = self.labels[idx]
        return image, label
    def __getname__(self):
        return self.names
    def __len__(self):
        return len(self.images)

adv_set = AdvDataset(root, transform=transform)
adv_names = adv_set.__getname__()
adv_loader = DataLoader(adv_set, batch_size=batch_size, shuffle=False)

print(f'number of images = {adv_set.__len__()}')
# Out:
# number of images = 200

# %% [markdown]
# ## Utils -- Benign Images Evaluation

# %%
# to evaluate the performance of model on benign images
def epoch_benign(model, loader, loss_fn):
    model.eval()
    train_acc, train_loss = 0.0, 0.0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        yp = model(x)
        loss = loss_fn(yp, y)
        train_acc += (yp.argmax(dim=1) == y).sum().item()
        train_loss += loss.item() * x.shape[0]
    return train_acc / len(loader.dataset), train_loss / len(loader.dataset)

# %% [markdown]
# ## Utils -- Attack Algorithm

# %%
# perform fgsm attack
def fgsm(model, x, y, loss_fn, epsilon=epsilon):
    x_adv = x.detach().clone() # initialize x_adv as original benign image x
    x_adv.requires_grad = True # need to obtain gradient of x_adv, thus set required grad
    loss = loss_fn(model(x_adv), y) # calculate loss
    loss.backward() # calculate gradient
    # fgsm: use gradient ascent on x_adv to maximize loss
    grad = x_adv.grad.detach()
    x_adv = x_adv + epsilon * grad.sign()
    return x_adv

# alpha and num_iter can be decided by yourself
alpha = 0.8/255/std

def ifgsm(model, x, y, loss_fn, epsilon=epsilon, alpha=alpha, num_iter=20):
    x_adv = x.detach().clone()
    ################ TODO: Medium baseline #######################
    # write a loop with num_iter times
    for i in range(num_iter):
      # TODO: Each iteration, execute fgsm
      # ref : https://colab.research.google.com/drive/1BcYS4bAInDCTo4Ilsc6w4o_SEoFTuHSO?usp=sharing#scrollTo=F_1wKfKyhrQW
      # x_adv = fgsm(model, x_adv, y, loss_fn, alpha) # call fgsm with (epsilon = alpha) to obtain new x_adv
      x_adv = x_adv.detach().clone()
      x_adv.requires_grad = True # need to obtain gradient of x_adv, thus set required grad
      loss = loss_fn(model(x_adv), y) # calculate loss
      loss.backward() # calculate gradient
      # fgsm: use gradient ascent on x_adv to maximize loss
      grad = x_adv.grad.detach()
      x_adv = x_adv + alpha * grad.sign()

      x_adv = torch.max(torch.min(x_adv, x+epsilon), x-epsilon) # clip new x_adv back to [x-epsilon, x+epsilon]

    return x_adv

def mifgsm(model, x, y, loss_fn, epsilon=epsilon, alpha=alpha, num_iter=20, decay=0.3):
    x_adv = x.detach().clone().to(device)
    # initialze momentum tensor
    momentum = torch.zeros_like(x).detach().to(device)

    ################ TODO: Strong baseline ####################
    for i in range(num_iter):
      # TODO: Refer to the algorithm of MI-FGSM
      # Calculate the momentum and update
      x_adv = x_adv.detach().clone()
      x_adv.requires_grad = True # need to obtain gradient of x_adv, thus set required grad
      loss = loss_fn(model(x_adv), y) # calculate loss
      loss.backward() # calculate gradient
      # TODO: Momentum calculation
      # ref : https://github.com/yuting-NTU/NTU-ML2022-Spring/blob/main/r10922196_hw10/ML2022_hw10.ipynb
      # ref : https://adversarial-attacks-pytorch.readthedocs.io/en/latest/_modules/torchattacks/attacks/mifgsm.html#MIFGSM
      grad = x_adv.grad.detach()
      grad = grad / torch.mean(torch.abs(grad), dim=(1,2,3), keepdim=True)
      grad = decay * momentum + grad
      momentum = grad
      x_adv = x_adv + alpha * grad.sign()
      x_adv = torch.max(torch.min(x_adv, x+epsilon), x-epsilon) # clip new x_adv back to [x-epsilon, x+epsilon]
    return x_adv




# ref : https://github.com/cihangxie/DI-2-FGSM/blob/master/attack.py
# ref : https://github.com/macTracyHuang/NTU-ML2022-Spring/blob/main/Hw10/ML2022_hw10-0.09.ipynb
def input_diversity(input_tensor):
    image_width = int(input_tensor.shape[-1] * 0.8)
    sz = input_tensor.shape[-1]

    rnd = torch.randint(image_width, sz, size=(1,), dtype=torch.int32)
    rescaled = F.interpolate(input_tensor, size=rnd)
    h_rem = sz - rnd
    w_rem = sz - rnd
    pad_top = torch.randint(0, h_rem.item(), size=(1,), dtype=torch.int32)
    pad_bottom = h_rem - pad_top
    pad_left = torch.randint(0, w_rem.item(), size=(1,), dtype=torch.int32)
    pad_right = w_rem - pad_left
    padded = F.pad(rescaled, (pad_left.item(), pad_right.item(), pad_top.item(), pad_bottom.item()), value=0)

    prob = torch.rand(1)
    # if prob < 0.999:
    #     return padded
    # else:
    #     return input_tensor
    return padded
def mifgsm_dim(model, x, y, loss_fn, epsilon=epsilon, alpha=alpha, num_iter=40, decay=1.0):
    x_adv = input_diversity(x)
    momentum = torch.zeros_like(x).detach().to(device)
    for i in range(num_iter):
        x_adv = x_adv.detach().clone()
        x_adv.requires_grad = True # need to obtain gradient of x_adv, thus set required grad
        loss = loss_fn(model(x_adv), y) # calculate loss
        loss.backward() # calculate gradient
        # TODO: Momentum calculation
        grad = x_adv.grad.detach()
        grad = grad / torch.mean(torch.abs(grad),(1,2,3),True)
        grad += decay * momentum
        momentum = grad
        x_adv = x_adv + alpha * grad.sign()
        x_adv = torch.max(torch.min(x_adv, x+epsilon), x-epsilon) # clip new x_adv back to [x-epsilon, x+epsilon]
    return x_adv

# from torchvision.transforms import InterpolationMode
# import torchvision.transforms.functional as F

# def dimmifgsm(model, x, y, loss_fn, epsilon=epsilon, alpha=alpha, num_iter=20, decay=1.0, prob=0.5):
#     image_size = x.size(3)      # Image's Height
#     # Do random crop and random padding
#     if random.random() < prob:
#         resize = int(random.uniform(16, image_size))
#         pad_top = int(random.uniform(0, image_size - resize))
#         pad_bottom = image_size - resize - pad_top
#         pad_left = int(random.uniform(0, image_size - resize))
#         pad_right = image_size - resize - pad_left
#         x_adv = F.resize(x, size=resize, interpolation=InterpolationMode.NEAREST)
#         x_adv = F.pad(x_adv, padding=[pad_left, pad_top, pad_right, pad_bottom], fill=0, padding_mode='constant')
#     else:
#         x_adv = x
#     # initialze momentum tensor
#     momentum = torch.zeros_like(x).detach().to(device)
#     # write a loop of num_iter to represent the iterative times
#     for i in range(num_iter):
#         x_adv = x_adv.detach().clone()
#         x_adv.requires_grad = True # need to obtain gradient of x_adv, thus set required grad
#         loss = loss_fn(model(x_adv), y) # calculate loss
#         loss.backward() # calculate gradient
#         # TODO: Momentum calculation
#         grad = x_adv.grad.detach()
#         grad = decay * momentum + (x_adv.grad / x_adv.grad.norm(1, dim=[1, 2, 3], keepdim=True))        # Get normalized gradient
#         momentum = grad
#         x_adv = x_adv + alpha * grad.sign()
#         x_adv = torch.max(torch.min(x_adv, x+epsilon), x-epsilon) # clip new x_adv back to [x-epsilon, x+epsilon]
#     return x_adv

# %% [markdown]
# ## Utils -- Attack
# * Recall
#   * ToTensor() can be seen as a function where $T(x) = x/255$.
#   * Normalize() can be seen as a function where $N(x) = (x-mean)/std$ where $mean$ and $std$ are constants.
#
# * Inverse function
#   * Inverse Normalize() can be seen as a function where $N^{-1}(x) = x*std+mean$ where $mean$ and $std$ are constants.
#   * Inverse ToTensor() can be seen as a function where $T^{-1}(x) = x*255$.
#
# * Special Noted
#   * ToTensor() will also convert the image from shape (height, width, channel) to shape (channel, height, width), so we also need to transpose the shape back to original shape.
#   * Since our dataloader samples a batch of data, what we need here is to transpose **(batch_size, channel, height, width)** back to **(batch_size, height, width, channel)** using np.transpose.

# %%
# perform adversarial attack and generate adversarial examples
def gen_adv_examples(model, loader, attack, loss_fn):
    model.eval()
    adv_names = []
    train_acc, train_loss = 0.0, 0.0
    for i, (x, y) in enumerate(loader):
        x, y = x.to(device), y.to(device)
        x_adv = attack(model, x, y, loss_fn) # obtain adversarial examples
        yp = model(x_adv)
        loss = loss_fn(yp, y)
        train_acc += (yp.argmax(dim=1) == y).sum().item()
        train_loss += loss.item() * x.shape[0]
        # store adversarial examples
        adv_ex = ((x_adv) * std + mean).clamp(0, 1) # to 0-1 scale
        adv_ex = (adv_ex * 255).clamp(0, 255) # 0-255 scale
        adv_ex = adv_ex.detach().cpu().data.numpy().round() # round to remove decimal part
        adv_ex = adv_ex.transpose((0, 2, 3, 1)) # transpose (bs, C, H, W) back to (bs, H, W, C)
        adv_examples = adv_ex if i == 0 else np.r_[adv_examples, adv_ex]
    return adv_examples, train_acc / len(loader.dataset), train_loss / len(loader.dataset)

# create directory which stores adversarial examples
def create_dir(data_dir, adv_dir, adv_examples, adv_names):
    if os.path.exists(adv_dir) is not True:
        _ = shutil.copytree(data_dir, adv_dir)
    for example, name in zip(adv_examples, adv_names):
        im = Image.fromarray(example.astype(np.uint8)) # image pixel value should be unsigned int
        im.save(os.path.join(adv_dir, name))

# %% [markdown]
# ## Model / Loss Function
#
# Model list is available [here](https://github.com/osmr/imgclsmob/blob/master/pytorch/pytorchcv/model_provider.py). Please select models which has _cifar10 suffix. Other kinds of models are prohibited, and it will be considered to be cheating if you use them.
#
# Note: Some of the models cannot be accessed/loaded. You can safely skip them since TA's model will not use those kinds of models.

# %%
# This function is used to check whether you use models pretrained on cifar10 instead of other datasets
# def model_checker(model_name):
#   assert ('cifar10' in model_name) and ('cifar100' not in model_name), 'The model selected is not pretrained on cifar10!'

# %%
# from pytorchcv.model_provider import get_model as ptcv_get_model

# model_name = 'resnet110_cifar10'
# model_checker(model_name)

# model = ptcv_get_model(model_name, pretrained=True).to(device)
# loss_fn = nn.CrossEntropyLoss()

# benign_acc, benign_loss = epoch_benign(model, adv_loader, loss_fn)
# print(f'benign_acc = {benign_acc:.5f}, benign_loss = {benign_loss:.5f}')

# %%
from pytorchcv.model_provider import get_model as ptcv_get_model
################ BOSS BASELINE ######################

class ensembleNet(nn.Module):
    def __init__(self, model_names):
        super().__init__()
        self.models = nn.ModuleList([ptcv_get_model(name, pretrained=True) for name in model_names])
        
    def forward(self, x):
        #################### TODO: boss baseline ###################
        ensemble_logits = []
        for i, m in enumerate(self.models):
        # TODO: sum up logits from multiple models
              ensemble_logits.append(m(x.clone()))
        total = sum(ensemble_logits)
        return total / len(ensemble_logits)
        # return ensemble_logits

# %%
##kaggle=0.09with_self
# model_names = [
#     'nin_cifar10',
#     'resnet110_cifar10',
#     'resnet56_cifar10',
#     'resnet20_cifar10',
#     'resnet1001_cifar10',
#     'seresnet110_cifar10',
#     'seresnet164bn_cifar10',
#     'sepreresnet20_cifar10',
#     'densenet40_k12_cifar10',
#     'densenet190_k40_bc_cifar10',
#     'densenet100_k12_cifar10',
#     'densenet40_k36_bc_cifar10',
    
#     # 'preresnet542bn_cifar10',
#     # 'seresnet20_cifar10',
#     # 'densenet40_k12_bc_cifar10',
#     # 'seresnet272bn_cifar10',
#     # 'seresnet542bn_cifar10',
#     # 'resnext29_16x64d_cifar10',
#     # 'preresnet110_cifar10',
#     # 'diaresnet20_cifar10',
#     # 'diapreresnet20_cifar10',
#     # 'pyramidnet110_a48_cifar10',
#     # 'densenet250_k24_bc_cifar10',
# ]


#kaggle=0.08with_kaggle
model_names = [
    'resnet20_cifar10',
    'resnet56_cifar10',
    'resnet110_cifar10',
    'resnet164bn_cifar10',
    'resnet272bn_cifar10',
    'resnet542bn_cifar10',
    'resnet1001_cifar10',
    'resnet1202_cifar10',
    'densenet40_k12_cifar10',
    'densenet40_k12_bc_cifar10',
    'densenet40_k24_bc_cifar10',
    'densenet40_k36_bc_cifar10',
    'densenet100_k12_cifar10',
    'densenet100_k24_cifar10',
    'densenet100_k12_bc_cifar10',
#     'densenet190_k40_bc_cifar10',
#     'densenet250_k24_bc_cifar10',

#     'resnext272_1x64d_cifar10',
#     'resnext272_2x32d_cifar10',
    'seresnet20_cifar10',
    'seresnet56_cifar10',
    'seresnet110_cifar10',
#     'seresnet164bn_cifar10',
#     'seresnet272bn_cifar10',
    'seresnet542bn_cifar10',
]


# model_names = [
#     'sepreresnet20_cifar10',
#     'seresnet164bn_cifar10',
#     # 'densenet190_k40_bc_cifar10',
#     'nin_cifar10',

#     'resnet20_cifar10',
#     'resnet56_cifar10',
#     'resnet110_cifar10',
#     'resnet164bn_cifar10',
#     'resnet272bn_cifar10',
#     'resnet542bn_cifar10',
#     'resnet1001_cifar10',
#     'resnet1202_cifar10',
#     'densenet40_k12_cifar10',
#     'densenet40_k12_bc_cifar10',
#     'densenet40_k24_bc_cifar10',
#     'densenet40_k36_bc_cifar10',
#     'densenet100_k12_cifar10',
#     'densenet100_k24_cifar10',
#     'densenet100_k12_bc_cifar10',
# #     'densenet190_k40_bc_cifar10',
# #     'densenet250_k24_bc_cifar10',

# #     'resnext272_1x64d_cifar10',
# #     'resnext272_2x32d_cifar10',
#     'seresnet20_cifar10',
#     'seresnet56_cifar10',
#     'seresnet110_cifar10',
# #     'seresnet164bn_cifar10',
# #     'seresnet272bn_cifar10',
#     'seresnet542bn_cifar10',
# ]


# for model_name in model_names:
#   model_checker(model_name)

ensemble_model = ensembleNet(model_names).to(device)
ensemble_model.eval()
# Out:
# ensembleNet(
#   (models): ModuleList(
#     (0): CIFARResNet(
#       (features): Sequential(
#         (init_block): ConvBlock(
#           (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activ): ReLU(inplace=True)
#         )
#         (stage1): Sequential(
#           (unit1): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (stage2): Sequential(
#           (unit1): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (identity_conv): ConvBlock(
#               (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (stage3): Sequential(
#           (unit1): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (identity_conv): ConvBlock(
#               (conv): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (final_pool): AvgPool2d(kernel_size=8, stride=1, padding=0)
#       )
#       (output): Linear(in_features=64, out_features=10, bias=True)
#     )
#     (1): CIFARResNet(
#       (features): Sequential(
#         (init_block): ConvBlock(
#           (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activ): ReLU(inplace=True)
#         )
#         (stage1): Sequential(
#           (unit1): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit4): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit5): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit6): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit7): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit8): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit9): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (stage2): Sequential(
#           (unit1): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (identity_conv): ConvBlock(
#               (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit4): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit5): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit6): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit7): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit8): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit9): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (stage3): Sequential(
#           (unit1): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (identity_conv): ConvBlock(
#               (conv): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit4): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit5): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit6): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit7): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit8): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit9): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (final_pool): AvgPool2d(kernel_size=8, stride=1, padding=0)
#       )
#       (output): Linear(in_features=64, out_features=10, bias=True)
#     )
#     (2): CIFARResNet(
#       (features): Sequential(
#         (init_block): ConvBlock(
#           (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activ): ReLU(inplace=True)
#         )
#         (stage1): Sequential(
#           (unit1): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit4): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit5): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit6): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit7): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit8): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit9): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit10): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit11): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit12): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit13): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit14): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit15): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit16): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit17): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit18): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (stage2): Sequential(
#           (unit1): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (identity_conv): ConvBlock(
#               (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit4): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit5): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit6): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit7): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit8): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit9): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit10): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit11): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit12): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit13): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...
#               (bn): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit9): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(204, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(204, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit10): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(216, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit11): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(228, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(228, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit12): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(240, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit13): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(252, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(252, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit14): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(264, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(264, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit15): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(276, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(276, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit16): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#         )
#         (stage3): Sequential(
#           (trans3): TransitionBlock(
#             (conv): PreConvBlock(
#               (bn): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(300, 150, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#           )
#           (unit1): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(150, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(150, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit2): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(162, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(162, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit3): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(174, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(174, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit4): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(186, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(186, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit5): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(198, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(198, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit6): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(210, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(210, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit7): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(222, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(222, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit8): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(234, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(234, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit9): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(246, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(246, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit10): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(258, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(258, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit11): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(270, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(270, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit12): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(282, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(282, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit13): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(294, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(294, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit14): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(306, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(306, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit15): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(318, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(318, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit16): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(330, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(330, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#         )
#         (post_activ): PreResActivation(
#           (bn): BatchNorm2d(342, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activ): ReLU(inplace=True)
#         )
#         (final_pool): AvgPool2d(kernel_size=8, stride=1, padding=0)
#       )
#       (output): Linear(in_features=342, out_features=10, bias=True)
#     )
#   )
# )

# %%
loss_fn = nn.CrossEntropyLoss()

benign_acc, benign_loss = epoch_benign(ensemble_model, adv_loader, loss_fn)
print(f'benign_acc = {benign_acc:.5f}, benign_loss = {benign_loss:.5f}')
# Out:
# benign_acc = 0.96500, benign_loss = 0.11379

# %% [markdown]
# ## FGSM

# %%
# adv_examples, fgsm_acc, fgsm_loss = gen_adv_examples(ensemble_model, adv_loader, fgsm, loss_fn)
# print(f'fgsm_acc = {fgsm_acc:.5f}, fgsm_loss = {fgsm_loss:.5f}')

# create_dir(root, 'fgsm', adv_examples, adv_names)

# %% [markdown]
# ## IFGSM

# %%
# adv_examples, ifgsm_acc, ifgsm_loss = gen_adv_examples(ensemble_model, adv_loader, ifgsm, loss_fn)
# print(f'ifgsm_acc = {ifgsm_acc:.5f}, ifgsm_loss = {ifgsm_loss:.5f}')

# create_dir(root, 'ifgsm', adv_examples, adv_names)

# %% [markdown]
# ## MIFGSM

# %%
# adv_examples, mifgsm_acc, mifgsm_loss = gen_adv_examples(ensemble_model, adv_loader, mifgsm, loss_fn)
# print(f'mifgsm_acc = {mifgsm_acc:.5f}, mifgsm_loss = {mifgsm_loss:.5f}')

# create_dir(root, 'mifgsm', adv_examples, adv_names)

# %% [markdown]
# ## MIFGSM_dim

# %%
adv_examples, mifgsm_dim_acc, mifgsm_dim_loss = gen_adv_examples(ensemble_model, adv_loader, mifgsm_dim, loss_fn)
print(f'mifgsm_dim_acc = {mifgsm_dim_acc:.5f}, mifgsm_dim_loss = {mifgsm_dim_loss:.5f}')

create_dir(root, 'mifgsm_dim', adv_examples, adv_names)


# adv_examples, dimmifgsm_acc, dimmifgsm_loss = gen_adv_examples(ensemble_model, adv_loader, dimmifgsm, loss_fn)
# print(f'dimmifgsm_acc = {dimmifgsm_acc:.5f}, dimmifgsm_loss = {dimmifgsm_loss:.5f}')

# create_dir(root, 'dimmifgsm', adv_examples, adv_names)
# Out:
# mifgsm_dim_acc = 0.01000, mifgsm_dim_loss = 13.84750

# %%
# %cd fgsm
# !tar zcvf ../fgsm.tgz *
# %cd ..

# %cd ifgsm
# !tar zcvf ../ifgsm.tgz *
# %cd ..

# %cd mifgsm
# !tar zcvf ../mifgsm.tgz *
# %cd ..

# %cd mifgsm_dim
# !tar zcvf ../mifgsm_dim.tgz *
# %cd ..

# %cd dimmifgsm
# !tar zcvf ../dimmifgsm.tgz *
# %cd ..
# Out:
# /mnt/c/Users/ccpy/Desktop/ntu/111-2/machine-learing/hw10/fgsm
# airplane/
# airplane/airplane1.png
# airplane/airplane10.png
# airplane/airplane11.png
# airplane/airplane12.png
# airplane/airplane13.png
# airplane/airplane14.png
# airplane/airplane15.png
# airplane/airplane16.png
# airplane/airplane17.png
# airplane/airplane18.png
# airplane/airplane19.png
# airplane/airplane2.png
# airplane/airplane20.png
# airplane/airplane3.png
# airplane/airplane4.png
# airplane/airplane5.png
# airplane/airplane6.png
# airplane/airplane7.png
# airplane/airplane8.png
# airplane/airplane9.png
# automobile/
# automobile/automobile1.png
# automobile/automobile10.png
# automobile/automobile11.png
# automobile/automobile12.png
# automobile/automobile13.png
# automobile/automobile14.png
# automobile/automobile15.png
# automobile/automobile16.png
# automobile/automobile17.png
# automobile/automobile18.png
# automobile/automobile19.png
# automobile/automobile2.png
# automobile/automobile20.png
# automobile/automobile3.png
# automobile/automobile4.png
# automobile/automobile5.png
# automobile/automobile6.png
# automobile/automobile7.png
# automobile/automobile8.png
# automobile/automobile9.png
# bird/
# bird/bird1.png
# bird/bird10.png
# bird/bird11.png
# bird/bird12.png
# bird/bird13.png
# bird/bird14.png
# bird/bird15.png
# bird/bird16.png
# bird/bird17.png
# bird/bird18.png
# bird/bird19.png
# bird/bird2.png
# bird/bird20.png
# bird/bird3.png
# bird/bird4.png
# bird/bird5.png
# bird/bird6.png
# bird/bird7.png
# bird/bird8.png
# bird/bird9.png
# cat/
# cat/cat1.png
# cat/cat10.png
# cat/cat11.png
# cat/cat12.png
# cat/cat13.png
# cat/cat14.png
# cat/cat15.png
# cat/cat16.png
# cat/cat17.png
# cat/cat18.png
# cat/cat19.png
# cat/cat2.png
# cat/cat20.png
# cat/cat3.png
# cat/cat4.png
# cat/cat5.png
# cat/cat6.png
# cat/cat7.png
# cat/cat8.png
# cat/cat9.png
# deer/
# deer/deer1.png
# deer/deer10.png
# deer/deer11.png
# deer/deer12.png
# deer/deer13.png
# deer/deer14.png
# deer/deer15.png
# deer/deer16.png
# deer/deer17.png
# deer/deer18.png
# deer/deer19.png
# deer/deer2.png
# deer/deer20.png
# deer/deer3.png
# deer/deer4.png
# deer/deer5.png
# deer/deer6.png
# deer/deer7.png
# deer/deer8.png
# deer/deer9.png
# dog/
# dog/dog1.png
# dog/dog10.png
# dog/dog11.png
# dog/dog12.png
# dog/dog13.png
# dog/dog14.png
# dog/dog15.png
# dog/dog16.png
# dog/dog17.png
# dog/dog18.png
# dog/dog19.png
# dog/dog2.png
# ship/ship17.png
# ship/ship18.png
# ship/ship19.png
# ship/ship2.png
# ship/ship20.png
# ship/ship3.png
# ship/ship4.png
# ship/ship5.png
# ship/ship6.png
# ship/ship7.png
# ship/ship8.png
# ship/ship9.png
# truck/
# truck/truck1.png
# truck/truck10.png
# truck/truck11.png
# truck/truck12.png
# truck/truck13.png
# truck/truck14.png
# truck/truck15.png
# truck/truck16.png
# truck/truck17.png
# truck/truck18.png
# truck/truck19.png
# truck/truck2.png
# truck/truck20.png
# truck/truck3.png
# truck/truck4.png
# truck/truck5.png
# truck/truck6.png
# truck/truck7.png
# truck/truck8.png
# truck/truck9.png
# /mnt/c/Users/ccpy/Desktop/ntu/111-2/machine-learing/hw10

# %%
from google.colab import files
files.download('fgsm.tgz')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from google.colab import files
#       2 files.download('fgsm.tgz')
#
# ModuleNotFoundError: No module named 'google.colab'

# %% [markdown]
# ## Example of Ensemble Attack
# * Ensemble multiple models as your proxy model to increase the black-box transferability ([paper](https://arxiv.org/abs/1611.02770))

# %%
################ BOSS BASELINE ######################

class ensembleNet(nn.Module):
    def __init__(self, model_names):
        super().__init__()
        self.models = nn.ModuleList([ptcv_get_model(name, pretrained=True) for name in model_names])
        
    def forward(self, x):
        #################### TODO: boss baseline ###################
        ensemble_logits = []
        for i, m in enumerate(self.models):
        # TODO: sum up logits from multiple models
              ensemble_logits.append(m(x.clone()))
        total = sum(ensemble_logits)
        return total / len(ensemble_logits)
        # return ensemble_logits

# %% [markdown]
# * Construct your ensemble model

# %%
model_names = [
    'nin_cifar10',
    'resnet110_cifar10',
    'resnet56_cifar10',
    'resnet20_cifar10',
    'resnet1001_cifar10',
    'seresnet110_cifar10',
    'seresnet164bn_cifar10',
    'sepreresnet20_cifar10',
    'densenet40_k12_cifar10',
    'densenet190_k40_bc_cifar10',
    'densenet100_k12_cifar10',
    'densenet40_k36_bc_cifar10',
    'resnext29_16x64d_cifar10',
    'preresnet110_cifar10',
    'diaresnet20_cifar10',
    'pyramidnet110_a48_cifar10',
    'densenet250_k24_bc_cifar10',
]

for model_name in model_names:
  model_checker(model_name)

ensemble_model = ensembleNet(model_names).to(device)
ensemble_model.eval()
# Out:
# Downloading /home/ccpy-ubuntu20045/.torch/models/nin_cifar10-0743-795b0824.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.175/nin_cifar10-0743-795b0824.pth.zip...
# Downloading /home/ccpy-ubuntu20045/.torch/models/resnet56_cifar10-0452-628c42a2.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.163/resnet56_cifar10-0452-628c42a2.pth.zip...
# Downloading /home/ccpy-ubuntu20045/.torch/models/resnet20_cifar10-0597-9b0024ac.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.163/resnet20_cifar10-0597-9b0024ac.pth.zip...
# Downloading /home/ccpy-ubuntu20045/.torch/models/resnet1001_cifar10-0328-77a179e2.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.201/resnet1001_cifar10-0328-77a179e2.pth.zip...
# Downloading /home/ccpy-ubuntu20045/.torch/models/seresnet110_cifar10-0363-1ddec230.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.362/seresnet110_cifar10-0363-1ddec230.pth.zip...
# Downloading /home/ccpy-ubuntu20045/.torch/models/seresnet164bn_cifar10-0339-1085dab6.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.362/seresnet164bn_cifar10-0339-1085dab6.pth.zip...
# Downloading /home/ccpy-ubuntu20045/.torch/models/sepreresnet20_cifar10-0618-eabb3fce.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.379/sepreresnet20_cifar10-0618-eabb3fce.pth.zip...
# Downloading /home/ccpy-ubuntu20045/.torch/models/densenet40_k12_cifar10-0561-8b8e8194.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.193/densenet40_k12_cifar10-0561-8b8e8194.pth.zip...
# Downloading /home/ccpy-ubuntu20045/.torch/models/densenet190_k40_bc_cifar10-0252-2896fa08.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.286/densenet190_k40_bc_cifar10-0252-2896fa08.pth.zip...
# Downloading /home/ccpy-ubuntu20045/.torch/models/densenet100_k12_cifar10-0366-26089c6e.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.205/densenet100_k12_cifar10-0366-26089c6e.pth.zip...
# Downloading /home/ccpy-ubuntu20045/.torch/models/densenet40_k36_bc_cifar10-0404-b1a4cc7e.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.224/densenet40_k36_bc_cifar10-0404-b1a4cc7e.pth.zip...
# Downloading /home/ccpy-ubuntu20045/.torch/models/resnext29_16x64d_cifar10-0241-4133d3d0.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.176/resnext29_16x64d_cifar10-0241-4133d3d0.pth.zip...
# Downloading /home/ccpy-ubuntu20045/.torch/models/preresnet110_cifar10-0386-cc08946a.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.164/preresnet110_cifar10-0386-cc08946a.pth.zip...
# Downloading /home/ccpy-ubuntu20045/.torch/models/diaresnet20_cifar10-0622-5e1a02bf.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.340/diaresnet20_cifar10-0622-5e1a02bf.pth.zip...
# Downloading /home/ccpy-ubuntu20045/.torch/models/pyramidnet110_a48_cifar10-0372-eb185645.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.184/pyramidnet110_a48_cifar10-0372-eb185645.pth.zip...
# Downloading /home/ccpy-ubuntu20045/.torch/models/densenet250_k24_bc_cifar10-0267-f8f9d305.pth.zip from https://github.com/osmr/imgclsmob/releases/download/v0.0.290/densenet250_k24_bc_cifar10-0267-f8f9d305.pth.zip...
# ensembleNet(
#   (models): ModuleList(
#     (0): CIFARNIN(
#       (features): Sequential(
#         (stage1): Sequential(
#           (unit1): NINConv(
#             (conv): Conv2d(3, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): NINConv(
#             (conv): Conv2d(192, 160, kernel_size=(1, 1), stride=(1, 1))
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): NINConv(
#             (conv): Conv2d(160, 96, kernel_size=(1, 1), stride=(1, 1))
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (stage2): Sequential(
#           (pool2): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#           (dropout2): Dropout(p=0.5, inplace=False)
#           (unit1): NINConv(
#             (conv): Conv2d(96, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): NINConv(
#             (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): NINConv(
#             (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (stage3): Sequential(
#           (pool3): AvgPool2d(kernel_size=3, stride=2, padding=1)
#           (dropout3): Dropout(p=0.5, inplace=False)
#           (unit1): NINConv(
#             (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): NINConv(
#             (conv): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#             (activ): ReLU(inplace=True)
#           )
#         )
#       )
#       (output): Sequential(
#         (final_conv): NINConv(
#           (conv): Conv2d(192, 10, kernel_size=(1, 1), stride=(1, 1))
#           (activ): ReLU(inplace=True)
#         )
#         (final_pool): AvgPool2d(kernel_size=8, stride=1, padding=0)
#       )
#     )
#     (1): CIFARResNet(
#       (features): Sequential(
#         (init_block): ConvBlock(
#           (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activ): ReLU(inplace=True)
#         )
#         (stage1): Sequential(
#           (unit1): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit4): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit5): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit6): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit7): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit8): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit9): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit10): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit11): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit12): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit13): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit14): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit15): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit16): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit17): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit18): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (stage2): Sequential(
#           (unit1): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (identity_conv): ConvBlock(
#               (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit4): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit5): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit6): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit7): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit8): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit9): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit10): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit11): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit12): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit13): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit14): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit15): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit16): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit17): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit18): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (stage3): Sequential(
#           (unit1): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (identity_conv): ConvBlock(
#               (conv): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#               (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit4): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit5): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit6): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit7): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit8): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit9): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit10): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit11): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit12): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit13): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit14): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit15): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit16): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit17): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit18): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#         )
#         (final_pool): AvgPool2d(kernel_size=8, stride=1, padding=0)
#       )
#       (output): Linear(in_features=64, out_features=10, bias=True)
#     )
#     (2): CIFARResNet(
#       (features): Sequential(
#         (init_block): ConvBlock(
#           (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activ): ReLU(inplace=True)
#         )
#         (stage1): Sequential(
#           (unit1): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit2): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit3): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit4): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit5): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit6): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit7): ResUnit(
#             (body): ResBlock(
#               (conv1): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (activ): ReLU(inplace=True)
#               )
#               (conv2): ConvBlock(
#                 (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                 (bn): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#             )
#             (activ): ReLU(inplace=True)
#           )
#           (unit8): ResUnit(
# ...
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit17): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1134, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1134, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit18): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1158, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1158, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit19): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1182, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1182, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit20): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1206, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1206, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit21): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1230, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1230, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit22): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1254, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1254, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit23): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1278, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1278, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit24): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1302, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1302, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit25): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1326, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1326, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit26): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1350, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1350, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit27): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1374, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1374, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit28): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1398, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1398, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit29): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1422, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1422, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit30): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1446, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1446, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit31): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1470, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1470, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit32): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1494, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1494, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit33): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1518, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1518, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit34): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1542, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1542, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit35): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1566, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1566, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit36): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1590, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1590, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit37): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1614, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1614, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit38): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1638, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1638, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit39): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1662, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1662, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit40): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1686, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1686, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#           (unit41): DenseUnit(
#             (conv1): PreConvBlock(
#               (bn): BatchNorm2d(1710, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(1710, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (conv2): PreConvBlock(
#               (bn): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (activ): ReLU(inplace=True)
#               (conv): Conv2d(96, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#           )
#         )
#         (post_activ): PreResActivation(
#           (bn): BatchNorm2d(1734, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (activ): ReLU(inplace=True)
#         )
#         (final_pool): AvgPool2d(kernel_size=8, stride=1, padding=0)
#       )
#       (output): Linear(in_features=1734, out_features=10, bias=True)
#     )
#   )
# )

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt

classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10, 20))
cnt = 0
for i, cls_name in enumerate(classes):
    path = f'{cls_name}/{cls_name}1.png'
    # benign image
    cnt += 1
    plt.subplot(len(classes), 4, cnt)
    im = Image.open(f'./data/{path}')
    logit = model(transform(im).unsqueeze(0).to(device))[0]
    predict = logit.argmax(-1).item()
    prob = logit.softmax(-1)[predict].item()
    plt.title(f'benign: {cls_name}1.png\n{classes[predict]}: {prob:.2%}')
    plt.axis('off')
    plt.imshow(np.array(im))
    # adversarial image
    cnt += 1
    plt.subplot(len(classes), 4, cnt)
    im = Image.open(f'./fgsm/{path}')
    logit = model(transform(im).unsqueeze(0).to(device))[0]
    predict = logit.argmax(-1).item()
    prob = logit.softmax(-1)[predict].item()
    plt.title(f'adversarial: {cls_name}1.png\n{classes[predict]}: {prob:.2%}')
    plt.axis('off')
    plt.imshow(np.array(im))
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 13
#      11 plt.subplot(len(classes), 4, cnt)
#      12 im = Image.open(f'./data/{path}')
# ---> 13 logit = model(transform(im).unsqueeze(0).to(device))[0]
#      14 predict = logit.argmax(-1).item()
#      15 prob = logit.softmax(-1)[predict].item()
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## Report Question
# * Make sure you follow below setup: the source model is "resnet110_cifar10", applying the vanilla fgsm attack on `dog2.png`. You can find the perturbed image in `fgsm/dog2.png`.

# %%
# original image
path = f'dog/dog2.png'
im = Image.open(f'./data/{path}')
logit = model(transform(im).unsqueeze(0).to(device))[0]
predict = logit.argmax(-1).item()
prob = logit.softmax(-1)[predict].item()
plt.title(f'benign: dog2.png\n{classes[predict]}: {prob:.2%}')
plt.axis('off')
plt.imshow(np.array(im))
plt.tight_layout()
plt.show()

# adversarial image 
adv_im = Image.open(f'./fgsm/{path}')
logit = model(transform(adv_im).unsqueeze(0).to(device))[0]
predict = logit.argmax(-1).item()
prob = logit.softmax(-1)[predict].item()
plt.title(f'adversarial: dog2.png\n{classes[predict]}: {prob:.2%}')
plt.axis('off')
plt.imshow(np.array(adv_im))
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       2 path = f'dog/dog2.png'
#       3 im = Image.open(f'./data/{path}')
# ----> 4 logit = model(transform(im).unsqueeze(0).to(device))[0]
#       5 predict = logit.argmax(-1).item()
#       6 prob = logit.softmax(-1)[predict].item()
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## Passive Defense - JPEG compression
# JPEG compression by imgaug package, compression rate set to 70
#
# Reference: https://imgaug.readthedocs.io/en/latest/source/api_augmenters_arithmetic.html#imgaug.augmenters.arithmetic.JpegCompression
#
# Note: If you haven't implemented the JPEG compression, this module will return an error. Don't worry about this.

# %%
import imgaug.augmenters as iaa

# pre-process image
x = transforms.ToTensor()(adv_im)*255
x = x.permute(1, 2, 0).numpy()
x = x.astype(np.uint8)

# TODO: use "imgaug" package to perform JPEG compression (compression rate = 70)
# compressed_x =  ... x .. 

logit = model(transform(compressed_x).unsqueeze(0).to(device))[0]
predict = logit.argmax(-1).item()
prob = logit.softmax(-1)[predict].item()
plt.title(f'JPEG adversarial: dog2.png\n{classes[predict]}: {prob:.2%}')
plt.axis('off')


plt.imshow(compressed_x)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-3792a8d5cb69> in <cell line: 11>()
#       9 # compressed_x =  ... x ..
#      10
# ---> 11 logit = model(transform(compressed_x).unsqueeze(0).to(device))[0]
#      12 predict = logit.argmax(-1).item()
#      13 prob = logit.softmax(-1)[predict].item()
#
# NameError: name 'compressed_x' is not defined
